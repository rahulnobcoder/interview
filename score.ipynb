# %%
import pandas as pd 

cd=pd.read_csv(r'output\1\combined_data.csv')
cd
# Out:
#       timestamps  video_index        fer   valence   arousal    stress  \
# 0       0.000000            1    neutral -0.136396  0.018287  0.289294
# 1       0.033333            1  surprised  0.167998  0.628403  0.338709
# 2       0.066667            1  surprised  0.168916  0.627339  0.338114
# 3       0.100000            1  surprised  0.167906  0.627929  0.338647
# 4       0.133333            1  surprised  0.169042  0.626766  0.337943
# ...          ...          ...        ...       ...       ...       ...
# 1405   46.833333            2    neutral -0.134145  0.017337  0.288452
# 1406   46.866667            2    neutral -0.133282  0.017398  0.288250
# 1407   46.900000            2    neutral -0.133571  0.017536  0.288362
# 1408   46.933333            2    neutral -0.133571  0.017536  0.288362
# 1409   46.966667            2    neutral -0.133571  0.017536  0.288362
#
#        eyebrow    blinks      yawn    smiles      pitches
# ...

# %%
cd['valence']>0.5
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1405    False
# 1406    False
# 1407    False
# 1408    False
# 1409    False
# Name: valence, Length: 1410, dtype: bool
